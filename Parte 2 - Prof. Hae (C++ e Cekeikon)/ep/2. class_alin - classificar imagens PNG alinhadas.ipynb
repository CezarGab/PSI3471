# %% [markdown]
# # **Cezar Gabriel M. A. Lima - 11806980**

# %% [markdown]
# **Acurácias de teste obtidas:** <br>
# S1 como treino: 96.00%  <br>
# S2 como treino: 98.00% <br>
# S3 como treino: 96.00% <br>
# S4 como treino: 94.00%  <br>
# S5 como treino: 96.00% <br>
#
# Média: 96.00%  <br>

# %%
(96 + 98 + 96 + 94 + 96) / 5
# Out:
# 96.0

# %% [markdown]
# # Baixando imagens:

# %%
url='https://drive.google.com/uc?export=download&id=1oJbH7442_bJxtO1KO0iz7NqBbqYxk7B6'

import requests
import os;

nomeArq="alinhados.zip"

if not os.path.exists(nomeArq):
  os.makedirs("rice_1to50")
  response = requests.get(url)

  if response.status_code == 200:
      with open(nomeArq, 'wb') as file:
          file.write(response.content)
      print("Download concluído com sucesso.")
  else:
      print("Falha ao baixar o arquivo.")
else:
 print("O arquivo",nomeArq,"ja existe no diretorio default",os.getcwd())

print("Descompactando arquivos novos de",nomeArq)
os.system(f"unzip -u {nomeArq} -d rice_1to50")
# Out:
# Download concluído com sucesso.
# Descompactando arquivos novos de alinhados.zip
# 0

# %% [markdown]
# # Separando S1, S2, S3, S4, S5:

# %%
import os
import re
import shutil

# Definir o caminho da pasta de origem
pasta_origem = "/content/rice_1to50"

# Criar as pastas de destino, se não existirem
pastas_destino = ["/content/S1", "/content/S2", "/content/S3", "/content/S4", "/content/S5"]
for pasta_destino in pastas_destino:
    if not os.path.exists(pasta_destino):
        os.makedirs(pasta_destino)

# Definir o número máximo de arquivos a serem copiados em cada pasta de destino
num_arquivos_por_pasta = 10

# Obter a lista de pastas da pasta de origem
pastas = [item for item in os.listdir(pasta_origem) if os.path.isdir(os.path.join(pasta_origem, item)) and item != "orientacao"]

for pasta in pastas:
    pasta_origem_completa = os.path.join(pasta_origem, pasta)

    # Obter a lista de arquivos que não são pastas na pasta atual
    arquivos = [item for item in os.listdir(pasta_origem_completa) if not os.path.isdir(os.path.join(pasta_origem_completa, item))]

    # Ordenar os arquivos usando uma função de classificação personalizada
    arquivos_ordenados = sorted(arquivos, key=lambda x: int(re.findall(r'\((\d+)\)', x)[0]))
    # Dividir os arquivos em grupos de tamanho "num_arquivos_por_pasta"
    grupos_arquivos = [arquivos_ordenados[i:i+num_arquivos_por_pasta] for i in range(0, len(arquivos_ordenados), num_arquivos_por_pasta)]

    # Para cada grupo de arquivos
    for i, grupo in enumerate(grupos_arquivos):
        # Definir o número da pasta de destino
        numero_pasta_destino = i + 1
        pasta_destino = f"/content/S{numero_pasta_destino}"

        # Copiar os arquivos para a pasta de destino
        for arquivo in grupo:
            arquivo_origem = os.path.join(pasta_origem_completa, arquivo)
            arquivo_destino = os.path.join(pasta_destino, arquivo)
            shutil.copy(arquivo_origem, arquivo_destino)

# %% [markdown]
# # Carregando imagens:

# %%
import os
import re
import numpy as np
from PIL import Image

def carregar_imagens_e_rotulos(pasta):
    imagens = []
    rotulos = []

    # Obter a lista de arquivos da pasta
    arquivos = os.listdir(pasta)

    # Para cada arquivo na pasta
    for arquivo in arquivos:
        # Caminho completo do arquivo
        caminho_arquivo = os.path.join(pasta, arquivo)

        # Carregar a imagem usando PIL
        imagem = Image.open(caminho_arquivo)

        # Converter a imagem para um array NumPy
        imagem_array = np.array(imagem)

        # Adicionar a imagem e o rótulo às listas
        imagens.append(imagem_array)
        rotulo = re.match(r'^(\w+)', arquivo).group(1)
        rotulos.append(rotulo)

    return np.array(imagens), np.array(rotulos)

pasta_s1 = "/content/S1"
pasta_s2 = "/content/S2"
pasta_s3 = "/content/S3"
pasta_s4 = "/content/S4"
pasta_s5 = "/content/S5"

# %%
# Carregar imagens e rótulos das pastas S2, S3, S4 e S5
AX1, rotulos_AX1 = carregar_imagens_e_rotulos(pasta_s1)
AX2, rotulos_AX2 = carregar_imagens_e_rotulos(pasta_s2)
AX3, rotulos_AX3 = carregar_imagens_e_rotulos(pasta_s3)
AX4, rotulos_AX4 = carregar_imagens_e_rotulos(pasta_s4)
AX5, rotulos_AX5 = carregar_imagens_e_rotulos(pasta_s5)

# %% [markdown]
# Primeiro, faremos o subconjunto S1 como teste e o restante como treinamento. Adiante, o mesmo ocorrerá para cada um dos subconjuntos sendo teste. Por fim, a média das acurácias será calculada.

# %%
# Concatenar as imagens e os rótulos de todas as pastas
AX = np.concatenate((AX2, AX3, AX4, AX5), axis=0)
rotulos_AX = np.concatenate((rotulos_AX2, rotulos_AX3, rotulos_AX4, rotulos_AX5), axis=0)

# Imprimir as formas dos arrays de imagens e rótulos
print("Shape de AX:", AX.shape)
print("Shape de rótulos_AX:", rotulos_AX.shape)

# Carregar imagens e rótulos da pasta S1
pasta_s1 = "/content/S1"

QX, rotulos_QX = carregar_imagens_e_rotulos(pasta_s1)

# Imprimir as formas dos arrays de imagens e rótulos
print("Shape de QX:", QX.shape)
print("Shape de rótulos_QX:", rotulos_QX.shape)
# Out:
# Shape de AX: (200, 250, 250, 3)
# Shape de rótulos_AX: (200,)
# Shape de QX: (50, 250, 250, 3)
# Shape de rótulos_QX: (50,)

# %%
from matplotlib import pyplot as plt
f = plt.figure(figsize=(10, 8))
plt.suptitle("Algumas imagens do conjunto de treino e seus rótulos:", size="20")

for i in range(20):
  f.add_subplot(4,5,i+1)
  plt.imshow( AX[i,:,:])
  plt.title(rotulos_AX[i])
  plt.axis("off");
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# one-hot encoding:
AY = LabelEncoder().fit_transform(rotulos_AX)
QY = LabelEncoder().fit_transform(rotulos_QX)

# %%
AX.shape
# Out:
# (200, 250, 250, 3)

# %% [markdown]
# # Configurando, treinando e realizando inferência na CNN (S1 como conjunto de teste):

# %%
#cnn1.py - pos2021
import os; os.environ['TF_CPP_MIN_LOG_LEVEL']='3'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
import tensorflow.keras as keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Conv2D, MaxPooling2D, Dense, Flatten, BatchNormalization
from tensorflow.keras import optimizers
import numpy as np; import sys; import os; from time import time

AX=255-AX; QX=255-QX
nclasses = 5

nl, nc = AX.shape[1], AX.shape[2]
AX = (AX.astype('float32') / 255.0)-0.5 # -0.5 a +0.5
QX = (QX.astype('float32') / 255.0)-0.5 # -0.5 a +0.5
AX = np.expand_dims(AX,axis=4) # AX [60000,28,28,1]
QX = np.expand_dims(QX,axis=4)

# %%
model = Sequential() #
model.add(Conv2D(20, kernel_size=(5,5), activation='relu', input_shape=(nl, nc, 3) ))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(40, kernel_size=(5,5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(200, activation='relu'))
model.add(Dense(nclasses, activation='softmax'))


from tensorflow.keras.utils import plot_model
plot_model(model, to_file='cnn1.png', show_shapes=True);

model.summary()
opt=optimizers.Adam()

model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

t0=time()

model.fit(AX, AY, batch_size=100, epochs=15, verbose=2)

t1=time(); print("Tempo de treino: %.2f s"%(t1-t0))

score = model.evaluate(QX, QY, verbose=False)
print('Test loss: %.4f'%(score[0]))
print('Test accuracy: %.2f %%'%(100*score[1]))
print('Test error: %.2f %%'%(100*(1-score[1])))

t2=time()

QP2=model.predict(QX); QP=np.argmax(QP2,1)

t3=time(); print("Tempo de predicao: %.2f s"%(t3-t2))

nerro=np.count_nonzero(QP-QY); print("nerro=%d"%(nerro))
model.save('cnn1.h5')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 246, 246, 20)      1520
#
#  max_pooling2d (MaxPooling2D  (None, 123, 123, 20)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 119, 119, 40)      20040
#
#  max_pooling2d_1 (MaxPooling  (None, 59, 59, 40)       0
#  2D)
#
#  flatten (Flatten)           (None, 139240)            0
#
#  dropout (Dropout)           (None, 139240)            0
#
#  dense (Dense)               (None, 200)               27848200
#
#  dense_1 (Dense)             (None, 5)                 1005
#
# =================================================================
# Total params: 27,870,765
# Trainable params: 27,870,765
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 2/2 - 15s - loss: 10.3756 - accuracy: 0.2300 - 15s/epoch - 7s/step
# Epoch 2/15
# 2/2 - 0s - loss: 11.9984 - accuracy: 0.3150 - 263ms/epoch - 131ms/step
# Epoch 3/15
# 2/2 - 0s - loss: 3.9616 - accuracy: 0.4250 - 263ms/epoch - 131ms/step
# Epoch 4/15
# 2/2 - 0s - loss: 1.5552 - accuracy: 0.5200 - 264ms/epoch - 132ms/step
# Epoch 5/15
# 2/2 - 0s - loss: 0.8392 - accuracy: 0.6500 - 262ms/epoch - 131ms/step
# Epoch 6/15
# 2/2 - 0s - loss: 0.6031 - accuracy: 0.8400 - 262ms/epoch - 131ms/step
# Epoch 7/15
# 2/2 - 0s - loss: 0.4743 - accuracy: 0.8450 - 265ms/epoch - 133ms/step
# Epoch 8/15
# 2/2 - 0s - loss: 0.3009 - accuracy: 0.9300 - 263ms/epoch - 131ms/step
# Epoch 9/15
# 2/2 - 0s - loss: 0.1976 - accuracy: 0.9650 - 265ms/epoch - 132ms/step
# Epoch 10/15
# 2/2 - 0s - loss: 0.1389 - accuracy: 0.9550 - 261ms/epoch - 131ms/step
# Epoch 11/15
# 2/2 - 0s - loss: 0.0929 - accuracy: 0.9750 - 264ms/epoch - 132ms/step
# Epoch 12/15
# 2/2 - 0s - loss: 0.0816 - accuracy: 0.9800 - 267ms/epoch - 134ms/step
# Epoch 13/15
# 2/2 - 0s - loss: 0.0573 - accuracy: 0.9850 - 261ms/epoch - 130ms/step
# Epoch 14/15
# 2/2 - 0s - loss: 0.0342 - accuracy: 0.9950 - 263ms/epoch - 131ms/step
# Epoch 15/15
# 2/2 - 0s - loss: 0.0264 - accuracy: 0.9950 - 260ms/epoch - 130ms/step
# Tempo de treino: 21.57 s
# Test loss: 0.1019
# Test accuracy: 96.00 %
# Test error: 4.00 %
# 2/2 [==============================] - 0s 14ms/step
# Tempo de predicao: 0.42 s
# nerro=2

# %%
#from tensorflow.keras.models import load_model
## Carregar o modelo
#model = load_model('cnn1 Test Acc: 94.h5')
## Fazer previsões usando o modelo carregado
#QP2 = model.predict(QX); QP=np.argmax(QP2,1)
#nerro=np.count_nonzero(QP-QY); print("nerro=%d"%(nerro))

# %% [markdown]
# # S2 como conjunto de teste

# %%
# Concatenar as imagens e os rótulos de todas as pastas
AX = np.concatenate((AX1, AX3, AX4, AX5), axis=0)
rotulos_AX = np.concatenate((rotulos_AX1, rotulos_AX3, rotulos_AX4, rotulos_AX5), axis=0)

QX, rotulos_QX = carregar_imagens_e_rotulos(pasta_s2)

# Imprimir as formas dos arrays de imagens e rótulos
print("Shape de AX:", AX.shape)
print("Shape de rótulos_AX:", rotulos_AX.shape)
print("Shape de QX:", QX.shape)
print("Shape de rótulos_QX:", rotulos_QX.shape)

# one-hot encoding:
AY = LabelEncoder().fit_transform(rotulos_AX)
QY = LabelEncoder().fit_transform(rotulos_QX)
# Out:
# Shape de AX: (200, 250, 250, 3)
# Shape de rótulos_AX: (200,)
# Shape de QX: (50, 250, 250, 3)
# Shape de rótulos_QX: (50,)

# %%
#cnn1.py - pos2021
import os; os.environ['TF_CPP_MIN_LOG_LEVEL']='3'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
import tensorflow.keras as keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Conv2D, MaxPooling2D, Dense, Flatten, BatchNormalization
from tensorflow.keras import optimizers
import numpy as np; import sys; import os; from time import time

AX=255-AX; QX=255-QX
nclasses = 5

nl, nc = AX.shape[1], AX.shape[2]
AX = (AX.astype('float32') / 255.0)-0.5 # -0.5 a +0.5
QX = (QX.astype('float32') / 255.0)-0.5 # -0.5 a +0.5
AX = np.expand_dims(AX,axis=4) # AX [60000,28,28,1]
QX = np.expand_dims(QX,axis=4)

# %%
model = Sequential() #
model.add(Conv2D(20, kernel_size=(5,5), activation='relu', input_shape=(nl, nc, 3) ))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(40, kernel_size=(5,5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(200, activation='relu'))
model.add(Dense(nclasses, activation='softmax'))


#from tensorflow.keras.utils import plot_model
#plot_model(model, to_file='cnn1.png', show_shapes=True);

model.summary()
opt=optimizers.Adam()

model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

t0=time()

model.fit(AX, AY, batch_size=100, epochs=15, verbose=2)

t1=time(); print("Tempo de treino: %.2f s"%(t1-t0))

score = model.evaluate(QX, QY, verbose=False)
print('Test loss: %.4f'%(score[0]))
print('Test accuracy: %.2f %%'%(100*score[1]))
print('Test error: %.2f %%'%(100*(1-score[1])))

t2=time()

QP2=model.predict(QX); QP=np.argmax(QP2,1)

t3=time(); print("Tempo de predicao: %.2f s"%(t3-t2))

nerro=np.count_nonzero(QP-QY); print("nerro=%d"%(nerro))
model.save('cnn2.h5')
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_14 (Conv2D)          (None, 246, 246, 20)      1520
#
#  max_pooling2d_14 (MaxPoolin  (None, 123, 123, 20)     0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 119, 119, 40)      20040
#
#  max_pooling2d_15 (MaxPoolin  (None, 59, 59, 40)       0
#  g2D)
#
#  flatten_7 (Flatten)         (None, 139240)            0
#
#  dropout_7 (Dropout)         (None, 139240)            0
#
#  dense_14 (Dense)            (None, 200)               27848200
#
#  dense_15 (Dense)            (None, 5)                 1005
#
# =================================================================
# Total params: 27,870,765
# Trainable params: 27,870,765
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 2/2 - 2s - loss: 968.7093 - accuracy: 0.2850 - 2s/epoch - 813ms/step
# Epoch 2/15
# 2/2 - 0s - loss: 757.0886 - accuracy: 0.3500 - 264ms/epoch - 132ms/step
# Epoch 3/15
# 2/2 - 0s - loss: 65.6878 - accuracy: 0.6300 - 234ms/epoch - 117ms/step
# Epoch 4/15
# 2/2 - 0s - loss: 21.7739 - accuracy: 0.7350 - 235ms/epoch - 118ms/step
# Epoch 5/15
# 2/2 - 0s - loss: 11.9177 - accuracy: 0.8350 - 231ms/epoch - 115ms/step
# Epoch 6/15
# 2/2 - 0s - loss: 6.0320 - accuracy: 0.8800 - 233ms/epoch - 117ms/step
# Epoch 7/15
# 2/2 - 0s - loss: 1.4445 - accuracy: 0.9600 - 235ms/epoch - 118ms/step
# Epoch 8/15
# 2/2 - 0s - loss: 0.5470 - accuracy: 0.9650 - 234ms/epoch - 117ms/step
# Epoch 9/15
# 2/2 - 0s - loss: 0.2868 - accuracy: 0.9850 - 229ms/epoch - 114ms/step
# Epoch 10/15
# 2/2 - 0s - loss: 0.1490 - accuracy: 0.9850 - 233ms/epoch - 117ms/step
# Epoch 11/15
# 2/2 - 0s - loss: 0.1239 - accuracy: 0.9900 - 238ms/epoch - 119ms/step
# Epoch 12/15
# 2/2 - 0s - loss: 0.2608 - accuracy: 0.9800 - 234ms/epoch - 117ms/step
# Epoch 13/15
# 2/2 - 0s - loss: 0.0654 - accuracy: 0.9950 - 235ms/epoch - 117ms/step
# Epoch 14/15
# 2/2 - 0s - loss: 0.2591 - accuracy: 0.9900 - 237ms/epoch - 119ms/step
# Epoch 15/15
# 2/2 - 0s - loss: 2.5807e-04 - accuracy: 1.0000 - 236ms/epoch - 118ms/step
# Tempo de treino: 5.14 s
# Test loss: 3.1985
# Test accuracy: 98.00 %
# Test error: 2.00 %
# 2/2 [==============================] - 0s 12ms/step
# Tempo de predicao: 0.20 s
# nerro=1

# %% [markdown]
# # S3 como conjunto de teste

# %%
# Concatenar as imagens e os rótulos de todas as pastas
AX = np.concatenate((AX1, AX2, AX4, AX5), axis=0)
rotulos_AX = np.concatenate((rotulos_AX1, rotulos_AX2, rotulos_AX4, rotulos_AX5), axis=0)

QX, rotulos_QX = carregar_imagens_e_rotulos(pasta_s3)

# Imprimir as formas dos arrays de imagens e rótulos
print("Shape de AX:", AX.shape)
print("Shape de rótulos_AX:", rotulos_AX.shape)
print("Shape de QX:", QX.shape)
print("Shape de rótulos_QX:", rotulos_QX.shape)

# one-hot encoding:
AY = LabelEncoder().fit_transform(rotulos_AX)
QY = LabelEncoder().fit_transform(rotulos_QX)
# Out:
# Shape de AX: (200, 250, 250, 3)
# Shape de rótulos_AX: (200,)
# Shape de QX: (50, 250, 250, 3)
# Shape de rótulos_QX: (50,)

# %%
model = Sequential() #
model.add(Conv2D(20, kernel_size=(5,5), activation='relu', input_shape=(nl, nc, 3) ))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(40, kernel_size=(5,5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(200, activation='relu'))
model.add(Dense(nclasses, activation='softmax'))


#from tensorflow.keras.utils import plot_model
#plot_model(model, to_file='cnn1.png', show_shapes=True);

model.summary()
opt=optimizers.Adam()

model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

t0=time()

model.fit(AX, AY, batch_size=100, epochs=15, verbose=2)

t1=time(); print("Tempo de treino: %.2f s"%(t1-t0))

score = model.evaluate(QX, QY, verbose=False)
print('Test loss: %.4f'%(score[0]))
print('Test accuracy: %.2f %%'%(100*score[1]))
print('Test error: %.2f %%'%(100*(1-score[1])))

t2=time()

QP2=model.predict(QX); QP=np.argmax(QP2,1)

t3=time(); print("Tempo de predicao: %.2f s"%(t3-t2))

nerro=np.count_nonzero(QP-QY); print("nerro=%d"%(nerro))
model.save('cnn3.h5')
# Out:
# Model: "sequential_181"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_362 (Conv2D)         (None, 246, 246, 20)      1520
#
#  max_pooling2d_362 (MaxPooli  (None, 123, 123, 20)     0
#  ng2D)
#
#  conv2d_363 (Conv2D)         (None, 119, 119, 40)      20040
#
#  max_pooling2d_363 (MaxPooli  (None, 59, 59, 40)       0
#  ng2D)
#
#  flatten_181 (Flatten)       (None, 139240)            0
#
#  dropout_181 (Dropout)       (None, 139240)            0
#
#  dense_362 (Dense)           (None, 200)               27848200
#
#  dense_363 (Dense)           (None, 5)                 1005
#
# =================================================================
# Total params: 27,870,765
# Trainable params: 27,870,765
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 2/2 - 2s - loss: 294.7902 - accuracy: 0.3350 - 2s/epoch - 832ms/step
# Epoch 2/15
# 2/2 - 0s - loss: 132.1292 - accuracy: 0.5150 - 240ms/epoch - 120ms/step
# Epoch 3/15
# 2/2 - 0s - loss: 2.0289 - accuracy: 0.9300 - 233ms/epoch - 116ms/step
# Epoch 4/15
# 2/2 - 0s - loss: 1.7872 - accuracy: 0.9400 - 236ms/epoch - 118ms/step
# Epoch 5/15
# 2/2 - 0s - loss: 0.7409 - accuracy: 0.9650 - 235ms/epoch - 118ms/step
# Epoch 6/15
# 2/2 - 0s - loss: 0.3832 - accuracy: 0.9700 - 231ms/epoch - 116ms/step
# Epoch 7/15
# 2/2 - 0s - loss: 0.0596 - accuracy: 0.9850 - 236ms/epoch - 118ms/step
# Epoch 8/15
# 2/2 - 0s - loss: 0.0711 - accuracy: 0.9900 - 238ms/epoch - 119ms/step
# Epoch 9/15
# 2/2 - 0s - loss: 0.0656 - accuracy: 0.9850 - 236ms/epoch - 118ms/step
# Epoch 10/15
# 2/2 - 0s - loss: 0.0503 - accuracy: 0.9900 - 239ms/epoch - 120ms/step
# Epoch 11/15
# 2/2 - 0s - loss: 0.0031 - accuracy: 1.0000 - 241ms/epoch - 121ms/step
# Epoch 12/15
# 2/2 - 0s - loss: 0.0092 - accuracy: 0.9950 - 238ms/epoch - 119ms/step
# Epoch 13/15
# 2/2 - 0s - loss: 0.0160 - accuracy: 0.9900 - 240ms/epoch - 120ms/step
# Epoch 14/15
# 2/2 - 0s - loss: 0.0136 - accuracy: 0.9950 - 245ms/epoch - 122ms/step
# Epoch 15/15
# 2/2 - 0s - loss: 1.1671e-04 - accuracy: 1.0000 - 228ms/epoch - 114ms/step
# Tempo de treino: 5.20 s
# Test loss: 0.2461
# Test accuracy: 96.00 %
# Test error: 4.00 %
# 2/2 [==============================] - 0s 10ms/step
# Tempo de predicao: 0.18 s
# nerro=2

# %%
from matplotlib import pyplot as plt

# Encontrar os índices em que QP-QY é diferente de zero
nonzero_indices = np.nonzero(QP-QY)[0]


fig, axs = plt.subplots(1, len(nonzero_indices), figsize=(15, 5))

rotulos_Q = ["Arborio", "Basmati", "Ipsala", "Jasmine", "Karacadag"]

for i, index in enumerate(nonzero_indices):
    axs[i].imshow(QX[index,:,:])
    axs[i].set_title(f"Índice: {index}, Rótulo correto: {rotulos_Q[QY[index]]}, Predição: {rotulos_Q[QP[index]]}", fontsize=10)
    axs[i].axis("off")

plt.suptitle("Erros na rede atual")
plt.tight_layout()
plt.show()

# %% [markdown]
# #S4 como conjunto de teste

# %%
# Concatenar as imagens e os rótulos de todas as pastas
AX = np.concatenate((AX1, AX2, AX3, AX5), axis=0)
rotulos_AX = np.concatenate((rotulos_AX1, rotulos_AX2, rotulos_AX3, rotulos_AX5), axis=0)

QX, rotulos_QX = carregar_imagens_e_rotulos(pasta_s4)

# Imprimir as formas dos arrays de imagens e rótulos
print("Shape de AX:", AX.shape)
print("Shape de rótulos_AX:", rotulos_AX.shape)
print("Shape de QX:", QX.shape)
print("Shape de rótulos_QX:", rotulos_QX.shape)

# one-hot encoding:
AY = LabelEncoder().fit_transform(rotulos_AX)
QY = LabelEncoder().fit_transform(rotulos_QX)
# Out:
# Shape de AX: (200, 250, 250, 3)
# Shape de rótulos_AX: (200,)
# Shape de QX: (50, 250, 250, 3)
# Shape de rótulos_QX: (50,)

# %%
model = Sequential() #
model.add(Conv2D(20, kernel_size=(5,5), activation='relu', input_shape=(nl, nc, 3) ))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(40, kernel_size=(5,5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(200, activation='relu'))
model.add(Dense(nclasses, activation='softmax'))


#from tensorflow.keras.utils import plot_model
#plot_model(model, to_file='cnn1.png', show_shapes=True);

model.summary()
opt=optimizers.Adam()

model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

t0=time()

model.fit(AX, AY, batch_size=100, epochs=15, verbose=2)

t1=time(); print("Tempo de treino: %.2f s"%(t1-t0))

score = model.evaluate(QX, QY, verbose=False)
print('Test loss: %.4f'%(score[0]))
print('Test accuracy: %.2f %%'%(100*score[1]))
print('Test error: %.2f %%'%(100*(1-score[1])))

t2=time()

QP2=model.predict(QX); QP=np.argmax(QP2,1)

t3=time(); print("Tempo de predicao: %.2f s"%(t3-t2))

nerro=np.count_nonzero(QP-QY); print("nerro=%d"%(nerro))
model.save('cnn4.h5')
# Out:
# Model: "sequential_53"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_106 (Conv2D)         (None, 246, 246, 20)      1520
#
#  max_pooling2d_106 (MaxPooli  (None, 123, 123, 20)     0
#  ng2D)
#
#  conv2d_107 (Conv2D)         (None, 119, 119, 40)      20040
#
#  max_pooling2d_107 (MaxPooli  (None, 59, 59, 40)       0
#  ng2D)
#
#  flatten_53 (Flatten)        (None, 139240)            0
#
#  dropout_53 (Dropout)        (None, 139240)            0
#
#  dense_106 (Dense)           (None, 200)               27848200
#
#  dense_107 (Dense)           (None, 5)                 1005
#
# =================================================================
# Total params: 27,870,765
# Trainable params: 27,870,765
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 2/2 - 2s - loss: 1007.2480 - accuracy: 0.2750 - 2s/epoch - 814ms/step
# Epoch 2/15
# 2/2 - 0s - loss: 476.8292 - accuracy: 0.3200 - 244ms/epoch - 122ms/step
# Epoch 3/15
# 2/2 - 0s - loss: 6.7533 - accuracy: 0.8750 - 245ms/epoch - 123ms/step
# Epoch 4/15
# 2/2 - 0s - loss: 2.6106 - accuracy: 0.8950 - 234ms/epoch - 117ms/step
# Epoch 5/15
# 2/2 - 0s - loss: 1.9036 - accuracy: 0.9100 - 237ms/epoch - 118ms/step
# Epoch 6/15
# 2/2 - 0s - loss: 0.9689 - accuracy: 0.9500 - 238ms/epoch - 119ms/step
# Epoch 7/15
# 2/2 - 0s - loss: 0.6769 - accuracy: 0.9550 - 236ms/epoch - 118ms/step
# Epoch 8/15
# 2/2 - 0s - loss: 0.5566 - accuracy: 0.9750 - 237ms/epoch - 119ms/step
# Epoch 9/15
# 2/2 - 0s - loss: 0.4786 - accuracy: 0.9550 - 239ms/epoch - 119ms/step
# Epoch 10/15
# 2/2 - 0s - loss: 0.2207 - accuracy: 0.9800 - 237ms/epoch - 118ms/step
# Epoch 11/15
# 2/2 - 0s - loss: 0.1550 - accuracy: 0.9850 - 238ms/epoch - 119ms/step
# Epoch 12/15
# 2/2 - 0s - loss: 0.0389 - accuracy: 0.9900 - 238ms/epoch - 119ms/step
# Epoch 13/15
# 2/2 - 0s - loss: 0.0376 - accuracy: 0.9950 - 236ms/epoch - 118ms/step
# Epoch 14/15
# 2/2 - 0s - loss: 0.0343 - accuracy: 0.9900 - 236ms/epoch - 118ms/step
# Epoch 15/15
# 2/2 - 0s - loss: 0.0842 - accuracy: 0.9850 - 235ms/epoch - 117ms/step
# Tempo de treino: 5.86 s
# Test loss: 1.1356
# Test accuracy: 94.00 %
# Test error: 6.00 %
# 2/2 [==============================] - 0s 12ms/step
# Tempo de predicao: 0.17 s
# nerro=3

# %% [markdown]
# #S5 como conjunto de teste

# %%
# Concatenar as imagens e os rótulos de todas as pastas
AX = np.concatenate((AX1, AX2, AX3, AX4), axis=0)
rotulos_AX = np.concatenate((rotulos_AX1, rotulos_AX2, rotulos_AX3, rotulos_AX4), axis=0)

QX, rotulos_QX = carregar_imagens_e_rotulos(pasta_s5)

# Imprimir as formas dos arrays de imagens e rótulos
print("Shape de AX:", AX.shape)
print("Shape de rótulos_AX:", rotulos_AX.shape)
print("Shape de QX:", QX.shape)
print("Shape de rótulos_QX:", rotulos_QX.shape)

# one-hot encoding:
AY = LabelEncoder().fit_transform(rotulos_AX)
QY = LabelEncoder().fit_transform(rotulos_QX)
# Out:
# Shape de AX: (200, 250, 250, 3)
# Shape de rótulos_AX: (200,)
# Shape de QX: (50, 250, 250, 3)
# Shape de rótulos_QX: (50,)

# %%
model = Sequential() #
model.add(Conv2D(20, kernel_size=(5,5), activation='relu', input_shape=(nl, nc, 3) ))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(40, kernel_size=(5,5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(200, activation='relu'))
model.add(Dense(nclasses, activation='softmax'))


#from tensorflow.keras.utils import plot_model
#plot_model(model, to_file='cnn1.png', show_shapes=True);

model.summary()
opt=optimizers.Adam()

model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

t0=time()

model.fit(AX, AY, batch_size=100, epochs=15, verbose=2)

t1=time(); print("Tempo de treino: %.2f s"%(t1-t0))

score = model.evaluate(QX, QY, verbose=False)
print('Test loss: %.4f'%(score[0]))
print('Test accuracy: %.2f %%'%(100*score[1]))
print('Test error: %.2f %%'%(100*(1-score[1])))

t2=time()

QP2=model.predict(QX); QP=np.argmax(QP2,1)

t3=time(); print("Tempo de predicao: %.2f s"%(t3-t2))

nerro=np.count_nonzero(QP-QY); print("nerro=%d"%(nerro))
model.save('cnn5.h5')
# Out:
# Model: "sequential_180"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_360 (Conv2D)         (None, 246, 246, 20)      1520
#
#  max_pooling2d_360 (MaxPooli  (None, 123, 123, 20)     0
#  ng2D)
#
#  conv2d_361 (Conv2D)         (None, 119, 119, 40)      20040
#
#  max_pooling2d_361 (MaxPooli  (None, 59, 59, 40)       0
#  ng2D)
#
#  flatten_180 (Flatten)       (None, 139240)            0
#
#  dropout_180 (Dropout)       (None, 139240)            0
#
#  dense_360 (Dense)           (None, 200)               27848200
#
#  dense_361 (Dense)           (None, 5)                 1005
#
# =================================================================
# Total params: 27,870,765
# Trainable params: 27,870,765
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 2/2 - 2s - loss: 453.9256 - accuracy: 0.3300 - 2s/epoch - 928ms/step
# Epoch 2/15
# 2/2 - 0s - loss: 529.8331 - accuracy: 0.5850 - 275ms/epoch - 138ms/step
# Epoch 3/15
# 2/2 - 0s - loss: 89.7819 - accuracy: 0.5800 - 240ms/epoch - 120ms/step
# Epoch 4/15
# 2/2 - 0s - loss: 16.5431 - accuracy: 0.6700 - 238ms/epoch - 119ms/step
# Epoch 5/15
# 2/2 - 0s - loss: 4.3953 - accuracy: 0.7500 - 243ms/epoch - 121ms/step
# Epoch 6/15
# 2/2 - 0s - loss: 1.6590 - accuracy: 0.7350 - 244ms/epoch - 122ms/step
# Epoch 7/15
# 2/2 - 0s - loss: 1.1829 - accuracy: 0.8300 - 238ms/epoch - 119ms/step
# Epoch 8/15
# 2/2 - 0s - loss: 0.6008 - accuracy: 0.9000 - 242ms/epoch - 121ms/step
# Epoch 9/15
# 2/2 - 0s - loss: 0.3031 - accuracy: 0.8950 - 237ms/epoch - 118ms/step
# Epoch 10/15
# 2/2 - 0s - loss: 0.2032 - accuracy: 0.9300 - 239ms/epoch - 120ms/step
# Epoch 11/15
# 2/2 - 0s - loss: 0.1057 - accuracy: 0.9450 - 239ms/epoch - 119ms/step
# Epoch 12/15
# 2/2 - 0s - loss: 0.0836 - accuracy: 0.9650 - 239ms/epoch - 120ms/step
# Epoch 13/15
# 2/2 - 0s - loss: 0.0435 - accuracy: 0.9850 - 237ms/epoch - 118ms/step
# Epoch 14/15
# 2/2 - 0s - loss: 0.0252 - accuracy: 0.9950 - 239ms/epoch - 120ms/step
# Epoch 15/15
# 2/2 - 0s - loss: 0.0238 - accuracy: 0.9950 - 235ms/epoch - 117ms/step
# Tempo de treino: 6.12 s
# Test loss: 0.2313
# Test accuracy: 96.00 %
# Test error: 4.00 %
# 2/2 [==============================] - 0s 10ms/step
# Tempo de predicao: 0.17 s
# nerro=2
